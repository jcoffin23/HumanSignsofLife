# %% [markdown]
# ## Training CNN Model ##
# #### Using only the heart beat with a single non moving frequency ####
#
#
# ### Load the Common Imports ###

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
from keras import Input as Input
from keras.datasets import mnist
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D,Conv1D
from keras.models import Sequential
from keras.layers import Dropout
from keras import layers
from keras.layers import BatchNormalization
import h5py

print(keras.__version__)
# Out:
# 2.4.3

# %% [markdown]
# # Load Mat Files

# %%
f = h5py.File('ML_genTrain_fs10k_1.mat','r')
arrays = {}

for k, v in f.items():
    arrays[k] = np.array(v)

# %%
print(arrays.keys())
print(datOut.shape)
print(datLabels.shape)
# Out:
# dict_keys(['datOut', 'fhActual', 'frActual', 't'])
# (10000, 20001)
# (10000, 1)

# %% [markdown]
# ### Load the Dataset ###

# %%
datOut= arrays['datOut']
datLabels = arrays['fhActual']

tNum = datOut.shape[0]


maxFreq = 1


firstLayerLength = 10000 #Length of the Model input, should not matter if data is correct length (1second at fs = 2k)
percentTrain = .9; #What percentange will be used to train (Reamining is test (10% test in this case))

trainEndEx = round(tNum*percentTrain) #Find out what index coresponds to 90% of the training data

x_train = datOut[0:trainEndEx,0:firstLayerLength] #Add training phase data to seperate array
y_train = datLabels[0:trainEndEx] / maxFreq #Add training labels to vector

x_test = datOut[trainEndEx+1:,0:firstLayerLength] #Add testing phase data to array
y_test = datLabels[trainEndEx+1:]/maxFreq #Add testting labels to vector





# convert the data to the right type
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')


print('x_test shape: ',x_test.shape)
print('x_train shape: ',x_train.shape)

print('y_test shape: ',y_test.shape)
print('y_train shape: ',y_train.shape)




print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_test shape:  (999, 10000)
# x_train shape:  (9000, 10000)
# y_test shape:  (999, 1)
# y_train shape:  (9000, 1)
# 9000 train samples
# 999 test samples

# %%
x = 50
t = np.arange(0,1,1/10000)
t = t[0:firstLayerLength]

plt.plot(t,x_train[x,:],t,x_train[1,:]) #Plot two training sample at random to verify output
plt.ylabel('Amplitude of Phase signal')
plt.xlabel('Time (s)')
plt.title('Two Training Samples')
plt.show()
print(y_train[x])
# Out:
# [1.377307]

# %% [markdown]
# # Set up Model

# %%
#Create model in spec to the prior research
model = Sequential()
model.add(Input(shape=(x_train.shape[1], )))

model.add(Dense(2,input_shape  = (x_train.shape[1],)))
model.add(Dense(2))
model.add(Dense(3))
model.add(Dense(1))

# %%
#set up optimizer and set the metric to MSE
model.compile(loss=keras.losses.mean_squared_error,
              optimizer=keras.optimizers.Nadam(learning_rate=0.001)
,
                  metrics=[keras.metrics.MeanSquaredError()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2)                 20002
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 9
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 20,021
# Trainable params: 20,021
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Convert class vectors to binary class matrices ###
#
# This is the one to use with the `categorical_crossentropy` loss.

# %%
batch_size = 100  # Set the batch size
epochs = 100 # Set the number of epochs

print(model.inputs[0].dtype)
# Out:
# <dtype: 'float32'>

# %% [markdown]
# ### Train the Model ###

# %%
# One Hidden Layer
initializer = keras.initializers.RandomNormal(mean=0., stddev=5.)

hist = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_split=0.18,
          callbacks=None)



score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/100
# 74/74 [==============================] - 2s 28ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 2/100
# 74/74 [==============================] - 2s 24ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 3/100
# 74/74 [==============================] - 2s 26ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 4/100
# 74/74 [==============================] - 2s 29ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 5/100
# 74/74 [==============================] - 2s 26ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 6/100
# 74/74 [==============================] - 2s 31ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 7/100
# 74/74 [==============================] - 2s 30ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 8/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 9/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 10/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 11/100
# 74/74 [==============================] - 2s 24ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 12/100
# 74/74 [==============================] - 2s 26ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 13/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 7.4858e-04 - val_mean_squared_error: 7.4858e-04
# Epoch 14/100
# 74/74 [==============================] - 2s 27ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 9.2972e-04 - val_mean_squared_error: 9.2972e-04
# Epoch 15/100
# 74/74 [==============================] - 2s 24ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 16/100
# 74/74 [==============================] - 2s 30ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 7.3874e-04 - val_mean_squared_error: 7.3874e-04
# Epoch 17/100
# 74/74 [==============================] - 2s 24ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.0660e-04 - val_mean_squared_error: 6.0660e-04
# Epoch 18/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 19/100
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 20/100
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 21/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 22/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 6.9120e-04 - val_mean_squared_error: 6.9120e-04
# Epoch 23/100
# 74/74 [==============================] - 3s 35ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 24/100
# 74/74 [==============================] - 3s 35ms/step - loss: 7.4632e-04 - mean_squared_error: 7.4632e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 25/100
# 74/74 [==============================] - 2s 24ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 26/100
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 5.4452e-04 - val_mean_squared_error: 5.4452e-04
# Epoch 27/100
# 74/74 [==============================] - 2s 22ms/step - loss: 8.0934e-04 - mean_squared_error: 8.0934e-04 - val_loss: 7.5359e-04 - val_mean_squared_error: 7.5359e-04
# Epoch 28/100
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 29/100
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 5.9426e-04 - val_mean_squared_error: 5.9426e-04
# Epoch 30/100
# 74/74 [==============================] - 2s 26ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.2365e-04 - val_mean_squared_error: 6.2365e-04
# Epoch 31/100
# 74/74 [==============================] - 2s 23ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.6952e-04 - val_mean_squared_error: 6.6952e-04
# Epoch 32/100
# 74/74 [==============================] - 1s 20ms/step - loss: 5.8667e-04 - mean_squared_error: 5.8667e-04 - val_loss: 5.0852e-04 - val_mean_squared_error: 5.0852e-04
# Epoch 33/100
# 74/74 [==============================] - 2s 28ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 7.8974e-04 - val_mean_squared_error: 7.8974e-04
# Epoch 34/100
# 74/74 [==============================] - 1s 14ms/step - loss: 5.9118e-04 - mean_squared_error: 5.9118e-04 - val_loss: 6.4451e-04 - val_mean_squared_error: 6.4451e-04
# Epoch 35/100
# 74/74 [==============================] - 2s 28ms/step - loss: 6.6491e-04 - mean_squared_error: 6.6491e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 36/100
# 74/74 [==============================] - 2s 29ms/step - loss: 9.8948e-04 - mean_squared_error: 9.8948e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 37/100
# 74/74 [==============================] - 2s 29ms/step - loss: 8.1224e-04 - mean_squared_error: 8.1224e-04 - val_loss: 5.0339e-04 - val_mean_squared_error: 5.0339e-04
# Epoch 38/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 39/100
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 5.6237e-04 - val_mean_squared_error: 5.6237e-04
# Epoch 40/100
# 74/74 [==============================] - 2s 21ms/step - loss: 6.2200e-04 - mean_squared_error: 6.2200e-04 - val_loss: 5.0688e-04 - val_mean_squared_error: 5.0688e-04
# Epoch 41/100
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 5.6659e-04 - val_mean_squared_error: 5.6659e-04
# Epoch 42/100
# 74/74 [==============================] - 2s 21ms/step - loss: 5.6879e-04 - mean_squared_error: 5.6879e-04 - val_loss: 5.4595e-04 - val_mean_squared_error: 5.4595e-04
# Epoch 43/100
# 74/74 [==============================] - 1s 18ms/step - loss: 7.7923e-04 - mean_squared_error: 7.7923e-04 - val_loss: 5.1153e-04 - val_mean_squared_error: 5.1153e-04
# Epoch 44/100
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 7.0972e-04 - val_mean_squared_error: 7.0972e-04
# Epoch 45/100
# 74/74 [==============================] - 2s 21ms/step - loss: 8.9345e-04 - mean_squared_error: 8.9345e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 46/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 47/100
# 74/74 [==============================] - 2s 24ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 5.9883e-04 - val_mean_squared_error: 5.9883e-04
# Epoch 48/100
# 74/74 [==============================] - 2s 30ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 49/100
# 74/74 [==============================] - 2s 28ms/step - loss: 9.7552e-04 - mean_squared_error: 9.7552e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 50/100
# 74/74 [==============================] - 2s 31ms/step - loss: 9.8818e-04 - mean_squared_error: 9.8818e-04 - val_loss: 7.0089e-04 - val_mean_squared_error: 7.0089e-04
# Epoch 51/100
# 74/74 [==============================] - 2s 31ms/step - loss: 6.5719e-04 - mean_squared_error: 6.5719e-04 - val_loss: 5.6242e-04 - val_mean_squared_error: 5.6242e-04
# Epoch 52/100
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 5.9320e-04 - val_mean_squared_error: 5.9320e-04
# Epoch 53/100
# 74/74 [==============================] - 2s 24ms/step - loss: 6.8018e-04 - mean_squared_error: 6.8018e-04 - val_loss: 6.8078e-04 - val_mean_squared_error: 6.8078e-04
# Epoch 54/100
# 74/74 [==============================] - 3s 35ms/step - loss: 7.1124e-04 - mean_squared_error: 7.1124e-04 - val_loss: 5.9188e-04 - val_mean_squared_error: 5.9188e-04
# Epoch 55/100
# 74/74 [==============================] - 2s 32ms/step - loss: 6.7503e-04 - mean_squared_error: 6.7503e-04 - val_loss: 5.3551e-04 - val_mean_squared_error: 5.3551e-04
# Epoch 56/100
# 74/74 [==============================] - 3s 35ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.4111e-04 - val_mean_squared_error: 5.4111e-04
# Epoch 57/100
# 74/74 [==============================] - 1s 13ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 5.7411e-04 - val_mean_squared_error: 5.7411e-04
# Epoch 58/100
# 74/74 [==============================] - 3s 36ms/step - loss: 6.5872e-04 - mean_squared_error: 6.5872e-04 - val_loss: 9.6142e-04 - val_mean_squared_error: 9.6142e-04
# Epoch 59/100
# 74/74 [==============================] - 1s 18ms/step - loss: 7.2038e-04 - mean_squared_error: 7.2038e-04 - val_loss: 6.0318e-04 - val_mean_squared_error: 6.0318e-04
# Epoch 60/100
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 61/100
# 74/74 [==============================] - 2s 30ms/step - loss: 6.8115e-04 - mean_squared_error: 6.8115e-04 - val_loss: 7.2526e-04 - val_mean_squared_error: 7.2526e-04
# Epoch 62/100
# 74/74 [==============================] - 2s 26ms/step - loss: 8.7106e-04 - mean_squared_error: 8.7106e-04 - val_loss: 7.5196e-04 - val_mean_squared_error: 7.5196e-04
# Epoch 63/100
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 64/100
# 74/74 [==============================] - 2s 24ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 65/100
# 74/74 [==============================] - 1s 9ms/step - loss: 9.3973e-04 - mean_squared_error: 9.3973e-04 - val_loss: 7.4665e-04 - val_mean_squared_error: 7.4665e-04
# Epoch 66/100
# 74/74 [==============================] - 1s 18ms/step - loss: 8.9612e-04 - mean_squared_error: 8.9612e-04 - val_loss: 5.2781e-04 - val_mean_squared_error: 5.2781e-04
# Epoch 67/100
# 74/74 [==============================] - 2s 31ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.1263e-04 - val_mean_squared_error: 5.1263e-04
# Epoch 68/100
# 74/74 [==============================] - 2s 27ms/step - loss: 7.7932e-04 - mean_squared_error: 7.7932e-04 - val_loss: 5.1298e-04 - val_mean_squared_error: 5.1298e-04
# Epoch 69/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 70/100
# 74/74 [==============================] - 2s 27ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.8238e-04 - val_mean_squared_error: 5.8238e-04
# Epoch 71/100
# 74/74 [==============================] - 3s 34ms/step - loss: 8.7914e-04 - mean_squared_error: 8.7914e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 72/100
# 74/74 [==============================] - 2s 29ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 5.6342e-04 - val_mean_squared_error: 5.6342e-04
# Epoch 73/100
# 74/74 [==============================] - 2s 24ms/step - loss: 6.1410e-04 - mean_squared_error: 6.1410e-04 - val_loss: 5.7809e-04 - val_mean_squared_error: 5.7809e-04
# Epoch 74/100
# 74/74 [==============================] - 1s 20ms/step - loss: 7.3847e-04 - mean_squared_error: 7.3847e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 75/100
# 74/74 [==============================] - 2s 28ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.1683e-04 - val_mean_squared_error: 6.1683e-04
# Epoch 76/100
# 74/74 [==============================] - 2s 26ms/step - loss: 7.2938e-04 - mean_squared_error: 7.2938e-04 - val_loss: 6.1940e-04 - val_mean_squared_error: 6.1940e-04
# Epoch 77/100
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.2217e-04 - val_mean_squared_error: 5.2217e-04
# Epoch 78/100
# 74/74 [==============================] - 1s 14ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 8.9025e-04 - val_mean_squared_error: 8.9025e-04
# Epoch 79/100
# 74/74 [==============================] - 1s 18ms/step - loss: 7.6108e-04 - mean_squared_error: 7.6108e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 80/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 81/100
# 74/74 [==============================] - 1s 18ms/step - loss: 8.0479e-04 - mean_squared_error: 8.0479e-04 - val_loss: 5.9270e-04 - val_mean_squared_error: 5.9270e-04
# Epoch 82/100
# 74/74 [==============================] - 2s 22ms/step - loss: 8.2021e-04 - mean_squared_error: 8.2021e-04 - val_loss: 5.1785e-04 - val_mean_squared_error: 5.1785e-04
# Epoch 83/100
# 74/74 [==============================] - 2s 25ms/step - loss: 5.8387e-04 - mean_squared_error: 5.8387e-04 - val_loss: 5.0897e-04 - val_mean_squared_error: 5.0897e-04
# Epoch 84/100
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 7.3264e-04 - val_mean_squared_error: 7.3264e-04
# Epoch 85/100
# 74/74 [==============================] - 2s 22ms/step - loss: 6.3337e-04 - mean_squared_error: 6.3337e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 86/100
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 5.6795e-04 - val_mean_squared_error: 5.6795e-04
# Epoch 87/100
# 74/74 [==============================] - 2s 23ms/step - loss: 7.5462e-04 - mean_squared_error: 7.5462e-04 - val_loss: 6.8204e-04 - val_mean_squared_error: 6.8204e-04
# Epoch 88/100
# 74/74 [==============================] - 2s 33ms/step - loss: 7.4843e-04 - mean_squared_error: 7.4843e-04 - val_loss: 6.1283e-04 - val_mean_squared_error: 6.1283e-04
# Epoch 89/100
# 74/74 [==============================] - 3s 35ms/step - loss: 8.3568e-04 - mean_squared_error: 8.3568e-04 - val_loss: 5.0083e-04 - val_mean_squared_error: 5.0083e-04
# Epoch 90/100
# 74/74 [==============================] - 2s 29ms/step - loss: 8.7719e-04 - mean_squared_error: 8.7719e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 91/100
# 74/74 [==============================] - 2s 24ms/step - loss: 9.8290e-04 - mean_squared_error: 9.8290e-04 - val_loss: 5.2169e-04 - val_mean_squared_error: 5.2169e-04
# Epoch 92/100
# 74/74 [==============================] - 2s 25ms/step - loss: 6.2972e-04 - mean_squared_error: 6.2972e-04 - val_loss: 6.1542e-04 - val_mean_squared_error: 6.1542e-04
# Epoch 93/100
# 74/74 [==============================] - 2s 31ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.4538e-04 - val_mean_squared_error: 5.4538e-04
# Epoch 94/100
# 74/74 [==============================] - 2s 26ms/step - loss: 7.6799e-04 - mean_squared_error: 7.6799e-04 - val_loss: 5.0335e-04 - val_mean_squared_error: 5.0335e-04
# Epoch 95/100
# 74/74 [==============================] - 2s 32ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.6995e-04 - val_mean_squared_error: 5.6995e-04
# Epoch 96/100
# 74/74 [==============================] - 3s 35ms/step - loss: 8.1554e-04 - mean_squared_error: 8.1554e-04 - val_loss: 6.9094e-04 - val_mean_squared_error: 6.9094e-04
# Epoch 97/100
# 74/74 [==============================] - 2s 26ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 9.2442e-04 - val_mean_squared_error: 9.2442e-04
# Epoch 98/100
# 74/74 [==============================] - 2s 31ms/step - loss: 6.6483e-04 - mean_squared_error: 6.6483e-04 - val_loss: 8.7611e-04 - val_mean_squared_error: 8.7611e-04
# Epoch 99/100
# 74/74 [==============================] - 3s 34ms/step - loss: 8.9577e-04 - mean_squared_error: 8.9577e-04 - val_loss: 5.5076e-04 - val_mean_squared_error: 5.5076e-04
# Epoch 100/100
# 74/74 [==============================] - 2s 32ms/step - loss: 6.1972e-04 - mean_squared_error: 6.1972e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Test loss: 0.0011346034007146955
# Test accuracy: 0.0011346034007146955

# %%
plt.plot(hist.history['mean_squared_error'])
plt.plot(hist.history['val_mean_squared_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Validation', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Validation', 'test'], loc='upper left')
plt.show()

# %%
print(hist.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %%
fEst = model.predict(x_test)

print(fEst.shape)
print(y_test.shape)
# Out:
# (999, 1)
# (999, 1)

# %%
x = 500
numShow = 10
t = np.arange(0,numShow,1)
plt.plot(t,y_test[x:x+numShow], t, fEst[x:x+numShow,0])
plt.ylabel('Frequency')
plt.xlabel('Test Num')
plt.legend(['Actual Frequency','Predicted Frequency'])
plt.title('Resp Rate Frequency Estimate Comparison')
plt.show()

# %%
x = 500
numShow = 50
t = np.arange(0,numShow,1)
plt.plot(t,np.abs(y_test[x:x+numShow,0] - fEst[x:x+numShow,0]))
plt.ylabel('Absolute Frequency Error')
plt.xlabel('Test Num')
plt.title('Absolute Heart Rate Freqeuncy Error Per Test')
plt.show()

# %%
x = 500
numShow = 50
t = np.arange(0,numShow,1)
plt.plot(t,np.abs(y_test[x:x+numShow,0] -fEst[x:x+numShow,0])/y_test[x:x+numShow,0])
plt.ylabel('Percentage Frequency Error')
plt.xlabel('Test Num')
plt.title('Percentage Heart Rate Freqeuncy Error Per Test')
plt.show()

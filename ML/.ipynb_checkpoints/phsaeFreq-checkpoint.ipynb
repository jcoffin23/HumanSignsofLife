# %% [markdown]
# ## Training Model with Full heart and Resp signals and HRV for Heart rate ##
#
# ### Load the Common Imports ###

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from keras import Input as Input
from keras.datasets import mnist
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D,Conv1D
from keras.models import Sequential
from keras.layers import Dropout
from keras import layers
from keras.layers import BatchNormalization
import h5py
from scipy import signal
print(keras.__version__)
# Out:
# 2.4.3

# %% [markdown]
# # Load Mat Files

# %%
f = h5py.File('ML_phaseFull_HRV.mat','r')
fs = 500
arrays = {}

for k, v in f.items():
    arrays[k] = np.array(v)

# %% [markdown]
# ### Load the Dataset ###

# %%
datOut= arrays['datOut']

numOfDat = datOut.shape[0]

heartLabels = arrays['FHA']
print('ff',heartLabels.shape,datOut.shape)
if heartLabels.shape[0] == datOut.shape[1]:
    heartLabels = heartLabels.transpose()
    print('Heart Labels was Transposed')
    
    
heartLabels = heartLabels[0:numOfDat,:]

respLabels = arrays['respActualMat']
respLabels = respLabels.transpose()
respLabels = respLabels[:,0:numOfDat]


datLabels = np.empty((2,numOfDat))


#datLabels[0,:] = respLabels
#datLabels[1,:] = heartLabels

datLabels = heartLabels
#datLabels= datLabels.transpose()


tNum = datOut.shape[0]


maxFreq = 1


percentTrain = .9;
trainEndEx = round(tNum*percentTrain)



x_train = datOut[0:trainEndEx,:]

#y_train = datLabels[0:trainEndEx,:] / maxFreq

y_train = datLabels[0:trainEndEx,:] / maxFreq


x_test = datOut[trainEndEx+1:,:]

#y_test = datLabels[trainEndEx+1:numOfDat,:]/maxFreq

y_test = datLabels[trainEndEx+1:numOfDat,:]/maxFreq


needToAppend = 1 #Set this flag so that we know to append the high Freq data to the end of this

# convert the data to the right type
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')



#Idiot check, the first dim should match between x_test and y_test (and train) 
#the second dim should match across all 4 data sets

print('x_train shape: ',x_train.shape)
print('y_train shape: ',y_train.shape)
print('x_test shape: ',x_test.shape)
print('y_test shape: ',y_test.shape)

print(x_train.shape[0], 'train samples') #Number of training samples
print(x_test.shape[0], 'test samples') #Number of testing Samples
# Out:
# ff (200, 25000) (200, 25000)
# x_train shape:  (180, 25000)
# y_train shape:  (180, 25000)
# x_test shape:  (19, 25000)
# y_test shape:  (19, 25000)
# 180 train samples
# 19 test samples

# %%
#Find spectrogram of approapate size
#SHOWN HERE IS LOG SCALE.
winSize = 4000  #This is the window size (found to work best for fs = 500)
fLimit = 75
win = signal.get_window('hamming',winSize) #Hamming window
f, t, Sxx = signal.spectrogram(x_train[0,:],window=win,nperseg=winSize ,fs = fs,noverlap=winSize-15,nfft= 10000) #Find spectrogram with high fft count
print(f.shape)
print(f[-1])
Sxx = Sxx[0:fLimit,:] #We only need FFT from 0 to 6 ish Hz which is about the first 100 samples at fs=500
f = f[0:fLimit]
idx=np.int0(t*fs)


y=y_train[0,idx]

plt.pcolormesh(t,f,(Sxx), shading='gouraud') #Plot it to confirm (Only for verification)
plt.plot(t,y)
plt.ylabel('Frequency [Hz]')
plt.title('Linear Spectrogram of single Trial')
plt.xlabel('Time [sec]')

plt.show()
print('Shape of Spectrogram',Sxx.shape)
# Out:
# (5001,)
# 250.0
# Shape of Spectrogram (75, 1401)

# %%
winSize = 2500  #This is the window size (found to work best for fs = 500)
oLap = winSize - 50 #This effects how long the spectorgram is in time (aswell as how good it is)
fLimit = 200
win = signal.get_window('hamming',winSize) #Hamming window

# %%
#This cell creates the training data (take 200 different spectrograms and append them one after another)
#Each stripe of data (vertically down the HZ) is a training point with a single bit of data

numSpecs = x_train.shape[0] #Number of spectrograms to create and append together (directly controls number of training smaples)


print('Total Data samples : ',y.shape[0] * numSpecs)
for k in range(0,numSpecs,1):
    f_train, t, Sxx = signal.spectrogram(x_train[k,:],window=win,fs = fs,noverlap=oLap,nfft= 10000) #Find spectrogram with high fft count
    Sxx = Sxx[0:fLimit,:]#We only need FFT from 0 to 3ish Hz which is about the first 50 samples at fs=500
    Sxx = 20*np.log10(Sxx) #Put into DB 
    f_train = f_train[0:fLimit]
    if k ==0:
        x_train_new = Sxx
        idx=np.int0(t*fs)
        y_train_new = y_train[k,idx]
    else:
        x_train_new = np.append(x_train_new,Sxx,1)
        y_train_new = np.append(y_train_new,y_train[k,idx])
# Out:
# Total Data samples :  252180

# %%
#Verify correct results>>
verifyNeeded=0
if verifyNeeded:
    
    t=np.linspace(0,40*numSpecs,x_train_new.shape[1])
    plt.pcolormesh(t,f,x_train_new, shading='gouraud') #Plot it to confirm (dont do this when actually finding it (duh))
    plt.plot(t,y_train_new)
    plt.ylabel('Frequency [Hz]')

    plt.xlabel('Time [sec]')
    #plt.xlim([0,100])
    #plt.ylim([0,2])
    plt.show()

# %%
#This cell creates the Testing data (take 20 different spectrograms and append them one after another)
#Each stripe of data (vertically down the HZ) is a training point with a single bit of data



for k in range(0,x_test.shape[0],1):
    f, t, Sxx = signal.spectrogram(x_test[k,:],window=win,fs = fs,noverlap=oLap,nfft= 10000) #Find spectrogram with high fft count
    Sxx = Sxx[0:fLimit,:] #We only need FFT from 0 to 3ish Hz which is about the first 50 samples at fs=500
    Sxx = 20*np.log10(Sxx)
    f = f[0:fLimit]
    if k ==0:
        x_test_new = Sxx
        idx=np.int0(t*fs)
        y_test_new = y_test[k,idx]
    else:
        x_test_new = np.append(x_test_new,Sxx,1)
        y_test_new = np.append(y_test_new,y_test[k,idx])

# %%
#Verify correct results>>


t=np.linspace(0,40*numSpecs,x_test_new.shape[1])
print(t[-1])
plt.pcolormesh(t,f,x_test_new, shading='gouraud') #Plot it to confirm (dont do this when actually finding it (duh))
plt.plot(t,y_test_new)
plt.ylabel('Frequency [Hz]')
plt.title('Spectrogram of Testing Data')
plt.xlabel('Time [sec]')
#plt.xlim([9500,10000])
#plt.ylim([0,4])
plt.show()
# Out:
# 7200.0

# %%
yy = x_test_new[:,100]

plt.plot(yy)
plt.ylabel('Magnitude')
plt.xlabel('Freq bin (Hz)')
plt.title('Single strip of Spectrogram data')
plt.show()

# %%
if x_train_new.shape[0]==x_test_new.shape[0]:
    x_train_new = np.transpose( x_train_new)
    x_test_new = np.transpose(x_test_new)

print('x_train_new shape:', x_train_new.shape)

print('x_test_new shape:', x_test_new.shape)

print('y_train_new shape:', y_train_new.shape)

print('y_test_new shape:', y_test_new.shape)
# Out:
# x_train_new shape: (81180, 200)
# x_test_new shape: (8569, 200)
# y_train_new shape: (81180,)
# y_test_new shape: (8569,)

# %% [markdown]
# # Shuffle the order of each training instance
#
# Now the data will not be several spectrograms appended together, but several FFT's appended together in random order from many many different spectrograms. This should cancle out any cross learning or wrong learning

# %%
lenTrain=x_train_new.shape[0]

#Create indexs that will be shuffled. These indexs will then be applied to both 
#                                                       the xdata and the y data (so the labels match)
#This is done so spectrograms now are not lined up in time domain and the data will look raindom

shuffleIdx = np.arange(0,lenTrain,1)
shuffleIdx = shuffle(shuffleIdx,random_state=None)

x_train_new = x_train_new[shuffleIdx,:]
y_train_new = y_train_new[shuffleIdx]

# %%
print(x_train_new.shape,f_train.shape,t.shape)
# Out:
# (81180, 200) (200,) (8569,)

# %% [markdown]
# # Set up Model

# %%
model = Sequential()
#model.add(Conv1D(5, 5, input_shape=(x_train.shape[1], 1)))
model.add(Input(shape=(x_train_new.shape[1], )))

model.add(Dense(2,input_shape  = (x_train_new.shape[1],)))
model.add(Dense(2))
model.add(Dense(3))
model.add(Dense(1))

# %%
#model.compile(loss=keras.losses.mean_squared_logarithmic_error,
#              optimizer=keras.optimizers.Adam(),
#                  metrics=[keras.metrics.MeanSquaredError()])
#model.summary()

model.compile(loss=keras.losses.mean_squared_error,
              optimizer=keras.optimizers.Nadam(learning_rate=0.001),metrics=[keras.metrics.mape])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 2)                 402
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 4
# =================================================================
# Total params: 421
# Trainable params: 421
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Convert class vectors to binary class matrices ###
#
# This is the one to use with the `categorical_crossentropy` loss.

# %%
batch_size = 100  # Set the batch size
epochs =100# Set the number of epochs
# One Hidden Layer
print(model.inputs[0].dtype)
# Out:
# <dtype: 'float32'>

# %% [markdown]
# ### Train the Model ###

# %%
# One Hidden Layer
initializer = keras.initializers.RandomNormal(mean=0., stddev=5.)

hist = model.fit(x_train_new, y_train_new,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_split=0.18,
          callbacks=None)
# Out:
# Epoch 1/100
# 666/666 [==============================] - 3s 4ms/step - loss: 346.7257 - mean_absolute_percentage_error: 801.7042 - val_loss: 29.4831 - val_mean_absolute_percentage_error: 308.7498
# Epoch 2/100
# 666/666 [==============================] - 2s 3ms/step - loss: 25.7999 - mean_absolute_percentage_error: 290.6607 - val_loss: 15.1166 - val_mean_absolute_percentage_error: 229.7177
# Epoch 3/100
# 666/666 [==============================] - 1s 2ms/step - loss: 11.8286 - mean_absolute_percentage_error: 197.8052 - val_loss: 6.7285 - val_mean_absolute_percentage_error: 149.3864
# Epoch 4/100
# 666/666 [==============================] - 1s 2ms/step - loss: 6.1024 - mean_absolute_percentage_error: 141.8542 - val_loss: 3.9352 - val_mean_absolute_percentage_error: 114.8766
# Epoch 5/100
# 666/666 [==============================] - 1s 2ms/step - loss: 3.6339 - mean_absolute_percentage_error: 110.4345 - val_loss: 2.3629 - val_mean_absolute_percentage_error: 87.9978
# Epoch 6/100
# 666/666 [==============================] - 1s 2ms/step - loss: 2.2636 - mean_absolute_percentage_error: 87.0023 - val_loss: 1.5194 - val_mean_absolute_percentage_error: 70.7085
# Epoch 7/100
# 666/666 [==============================] - 1s 1ms/step - loss: 1.4298 - mean_absolute_percentage_error: 68.7691 - val_loss: 0.9876 - val_mean_absolute_percentage_error: 57.1059
# Epoch 8/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.9093 - mean_absolute_percentage_error: 54.8988 - val_loss: 0.6075 - val_mean_absolute_percentage_error: 44.7637
# Epoch 9/100
# 666/666 [==============================] - 3s 5ms/step - loss: 0.5635 - mean_absolute_percentage_error: 43.1910 - val_loss: 0.3790 - val_mean_absolute_percentage_error: 35.1764
# Epoch 10/100
# 666/666 [==============================] - 3s 5ms/step - loss: 0.3452 - mean_absolute_percentage_error: 33.6305 - val_loss: 0.2362 - val_mean_absolute_percentage_error: 27.7028
# Epoch 11/100
# 666/666 [==============================] - 2s 3ms/step - loss: 0.2159 - mean_absolute_percentage_error: 26.5852 - val_loss: 0.1641 - val_mean_absolute_percentage_error: 22.8566
# Epoch 12/100
# 666/666 [==============================] - 2s 3ms/step - loss: 0.1391 - mean_absolute_percentage_error: 21.2688 - val_loss: 0.1006 - val_mean_absolute_percentage_error: 17.9334
# Epoch 13/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0919 - mean_absolute_percentage_error: 17.2448 - val_loss: 0.0721 - val_mean_absolute_percentage_error: 15.5276
# Epoch 14/100
# 666/666 [==============================] - 2s 3ms/step - loss: 0.0676 - mean_absolute_percentage_error: 14.7177 - val_loss: 0.0577 - val_mean_absolute_percentage_error: 13.0958
# Epoch 15/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0523 - mean_absolute_percentage_error: 12.8315 - val_loss: 0.0438 - val_mean_absolute_percentage_error: 11.8392
# Epoch 16/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0425 - mean_absolute_percentage_error: 11.4999 - val_loss: 0.0365 - val_mean_absolute_percentage_error: 10.6499
# Epoch 17/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0364 - mean_absolute_percentage_error: 10.5433 - val_loss: 0.0325 - val_mean_absolute_percentage_error: 9.7829
# Epoch 18/100
# 666/666 [==============================] - 2s 2ms/step - loss: 0.0307 - mean_absolute_percentage_error: 9.6641 - val_loss: 0.0274 - val_mean_absolute_percentage_error: 9.1366
# Epoch 19/100
# 666/666 [==============================] - 3s 5ms/step - loss: 0.0273 - mean_absolute_percentage_error: 9.0949 - val_loss: 0.0249 - val_mean_absolute_percentage_error: 8.4869
# Epoch 20/100
# 666/666 [==============================] - 2s 2ms/step - loss: 0.0237 - mean_absolute_percentage_error: 8.4763 - val_loss: 0.0217 - val_mean_absolute_percentage_error: 8.1687
# Epoch 21/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0219 - mean_absolute_percentage_error: 8.0903 - val_loss: 0.0195 - val_mean_absolute_percentage_error: 7.7223
# Epoch 22/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0197 - mean_absolute_percentage_error: 7.6744 - val_loss: 0.0187 - val_mean_absolute_percentage_error: 7.3325
# Epoch 23/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0182 - mean_absolute_percentage_error: 7.3527 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 7.7301
# Epoch 24/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0166 - mean_absolute_percentage_error: 7.0818 - val_loss: 0.0231 - val_mean_absolute_percentage_error: 9.5914
# Epoch 25/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0164 - mean_absolute_percentage_error: 7.0620 - val_loss: 0.0139 - val_mean_absolute_percentage_error: 6.3396
# Epoch 26/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0153 - mean_absolute_percentage_error: 6.7741 - val_loss: 0.0185 - val_mean_absolute_percentage_error: 8.5552
# Epoch 27/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0141 - mean_absolute_percentage_error: 6.5745 - val_loss: 0.0307 - val_mean_absolute_percentage_error: 12.0141
# Epoch 28/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0145 - mean_absolute_percentage_error: 6.5747 - val_loss: 0.0128 - val_mean_absolute_percentage_error: 6.0445
# Epoch 29/100
# 666/666 [==============================] - 1s 982us/step - loss: 0.0136 - mean_absolute_percentage_error: 6.4031 - val_loss: 0.0137 - val_mean_absolute_percentage_error: 7.0314
# Epoch 30/100
# 666/666 [==============================] - 2s 3ms/step - loss: 0.0129 - mean_absolute_percentage_error: 6.2410 - val_loss: 0.0159 - val_mean_absolute_percentage_error: 7.6721
# Epoch 31/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0122 - mean_absolute_percentage_error: 5.9856 - val_loss: 0.0106 - val_mean_absolute_percentage_error: 5.4489
# Epoch 32/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0122 - mean_absolute_percentage_error: 6.0542 - val_loss: 0.0104 - val_mean_absolute_percentage_error: 5.6469
# Epoch 33/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0114 - mean_absolute_percentage_error: 5.8135 - val_loss: 0.0104 - val_mean_absolute_percentage_error: 5.7015
# Epoch 34/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0111 - mean_absolute_percentage_error: 5.7507 - val_loss: 0.0100 - val_mean_absolute_percentage_error: 5.3664
# Epoch 35/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0111 - mean_absolute_percentage_error: 5.7174 - val_loss: 0.0100 - val_mean_absolute_percentage_error: 5.3648
# Epoch 36/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0111 - mean_absolute_percentage_error: 5.7254 - val_loss: 0.0098 - val_mean_absolute_percentage_error: 5.1883
# Epoch 37/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0112 - mean_absolute_percentage_error: 5.6779 - val_loss: 0.0157 - val_mean_absolute_percentage_error: 8.1531
# Epoch 38/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0110 - mean_absolute_percentage_error: 5.6722 - val_loss: 0.0133 - val_mean_absolute_percentage_error: 6.4755
# Epoch 39/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0107 - mean_absolute_percentage_error: 5.5845 - val_loss: 0.0091 - val_mean_absolute_percentage_error: 5.0882
# Epoch 40/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0111 - mean_absolute_percentage_error: 5.6597 - val_loss: 0.0090 - val_mean_absolute_percentage_error: 5.0256
# Epoch 41/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0101 - mean_absolute_percentage_error: 5.4241 - val_loss: 0.0089 - val_mean_absolute_percentage_error: 5.1224
# Epoch 42/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0105 - mean_absolute_percentage_error: 5.5432 - val_loss: 0.0143 - val_mean_absolute_percentage_error: 7.4582
# Epoch 43/100
# 666/666 [==============================] - 2s 3ms/step - loss: 0.0102 - mean_absolute_percentage_error: 5.4612 - val_loss: 0.0095 - val_mean_absolute_percentage_error: 5.0393
# Epoch 44/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0101 - mean_absolute_percentage_error: 5.3974 - val_loss: 0.0091 - val_mean_absolute_percentage_error: 5.1013
# Epoch 45/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0100 - mean_absolute_percentage_error: 5.3550 - val_loss: 0.0105 - val_mean_absolute_percentage_error: 5.3823
# Epoch 46/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0099 - mean_absolute_percentage_error: 5.3048 - val_loss: 0.0089 - val_mean_absolute_percentage_error: 5.0276
# Epoch 47/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0097 - mean_absolute_percentage_error: 5.1984 - val_loss: 0.0096 - val_mean_absolute_percentage_error: 5.0076
# Epoch 48/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0100 - mean_absolute_percentage_error: 5.3386 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 4.7953
# Epoch 49/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0099 - mean_absolute_percentage_error: 5.3012 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 4.8837
# Epoch 50/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0096 - mean_absolute_percentage_error: 5.2359 - val_loss: 0.0096 - val_mean_absolute_percentage_error: 5.5236
# Epoch 51/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_percentage_error: 5.1996 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 5.0831
# Epoch 52/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0095 - mean_absolute_percentage_error: 5.1718 - val_loss: 0.0104 - val_mean_absolute_percentage_error: 5.4579
# Epoch 53/100
# 666/666 [==============================] - 2s 2ms/step - loss: 0.0092 - mean_absolute_percentage_error: 5.1266 - val_loss: 0.0092 - val_mean_absolute_percentage_error: 5.4620
# Epoch 54/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0094 - mean_absolute_percentage_error: 5.1601 - val_loss: 0.0089 - val_mean_absolute_percentage_error: 5.1876
# Epoch 55/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0095 - mean_absolute_percentage_error: 5.1688 - val_loss: 0.0096 - val_mean_absolute_percentage_error: 5.5379
# Epoch 56/100
# 666/666 [==============================] - 2s 3ms/step - loss: 0.0093 - mean_absolute_percentage_error: 5.1137 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 4.8673
# Epoch 57/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_percentage_error: 5.1158 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 4.8968
# Epoch 58/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0093 - mean_absolute_percentage_error: 5.1171 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 4.6917
# Epoch 59/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0096 - mean_absolute_percentage_error: 5.2105 - val_loss: 0.0084 - val_mean_absolute_percentage_error: 4.8107
# Epoch 60/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0093 - mean_absolute_percentage_error: 5.1362 - val_loss: 0.0091 - val_mean_absolute_percentage_error: 5.1644
# Epoch 61/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0091 - mean_absolute_percentage_error: 5.0156 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 4.8628
# Epoch 62/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0091 - mean_absolute_percentage_error: 5.0923 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 5.0389
# Epoch 63/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0090 - mean_absolute_percentage_error: 5.0030 - val_loss: 0.0105 - val_mean_absolute_percentage_error: 5.9050
# Epoch 64/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0091 - mean_absolute_percentage_error: 5.1095 - val_loss: 0.0097 - val_mean_absolute_percentage_error: 5.2073
# Epoch 65/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0089 - mean_absolute_percentage_error: 5.0006 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 4.6266
# Epoch 66/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0089 - mean_absolute_percentage_error: 4.9899 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 4.6505
# Epoch 67/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0092 - mean_absolute_percentage_error: 5.1039 - val_loss: 0.0099 - val_mean_absolute_percentage_error: 5.8671
# Epoch 68/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0092 - mean_absolute_percentage_error: 5.0605 - val_loss: 0.0111 - val_mean_absolute_percentage_error: 6.0675
# Epoch 69/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9859 - val_loss: 0.0084 - val_mean_absolute_percentage_error: 4.9169
# Epoch 70/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0088 - mean_absolute_percentage_error: 4.9752 - val_loss: 0.0093 - val_mean_absolute_percentage_error: 4.9751
# Epoch 71/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0091 - mean_absolute_percentage_error: 5.0866 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 4.8790
# Epoch 72/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0088 - mean_absolute_percentage_error: 4.9237 - val_loss: 0.0080 - val_mean_absolute_percentage_error: 4.5831
# Epoch 73/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0086 - mean_absolute_percentage_error: 4.9540 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.6345
# Epoch 74/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9462 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.7117
# Epoch 75/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0090 - mean_absolute_percentage_error: 5.0387 - val_loss: 0.0088 - val_mean_absolute_percentage_error: 4.9794
# Epoch 76/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9490 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 4.7490
# Epoch 77/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0088 - mean_absolute_percentage_error: 4.9843 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.5750
# Epoch 78/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9144 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 4.6101
# Epoch 79/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0086 - mean_absolute_percentage_error: 4.9142 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.5506
# Epoch 80/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9841 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 4.9123
# Epoch 81/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9093 - val_loss: 0.0080 - val_mean_absolute_percentage_error: 4.8059
# Epoch 82/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0086 - mean_absolute_percentage_error: 4.9123 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 4.9900
# Epoch 83/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9189 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 4.7399
# Epoch 84/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0085 - mean_absolute_percentage_error: 4.8806 - val_loss: 0.0095 - val_mean_absolute_percentage_error: 5.2649
# Epoch 85/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9589 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.5482
# Epoch 86/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0084 - mean_absolute_percentage_error: 4.8786 - val_loss: 0.0098 - val_mean_absolute_percentage_error: 5.3011
# Epoch 87/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0088 - mean_absolute_percentage_error: 4.9202 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 4.5959
# Epoch 88/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0084 - mean_absolute_percentage_error: 4.8202 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.5274
# Epoch 89/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0085 - mean_absolute_percentage_error: 4.8979 - val_loss: 0.0084 - val_mean_absolute_percentage_error: 4.8363
# Epoch 90/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0084 - mean_absolute_percentage_error: 4.8454 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 4.5828
# Epoch 91/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0088 - mean_absolute_percentage_error: 4.9132 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 4.5843
# Epoch 92/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0083 - mean_absolute_percentage_error: 4.7800 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 4.6585
# Epoch 93/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0090 - mean_absolute_percentage_error: 5.0157 - val_loss: 0.0093 - val_mean_absolute_percentage_error: 5.0850
# Epoch 94/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0085 - mean_absolute_percentage_error: 4.8545 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.5620
# Epoch 95/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0084 - mean_absolute_percentage_error: 4.8506 - val_loss: 0.0091 - val_mean_absolute_percentage_error: 4.8664
# Epoch 96/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0087 - mean_absolute_percentage_error: 4.9404 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 4.8767
# Epoch 97/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0085 - mean_absolute_percentage_error: 4.8898 - val_loss: 0.0101 - val_mean_absolute_percentage_error: 5.3987
# Epoch 98/100
# 666/666 [==============================] - 1s 1ms/step - loss: 0.0085 - mean_absolute_percentage_error: 4.8475 - val_loss: 0.0078 - val_mean_absolute_percentage_error: 4.6193
# Epoch 99/100
# 666/666 [==============================] - 1s 2ms/step - loss: 0.0084 - mean_absolute_percentage_error: 4.8178 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 4.6620
# Epoch 100/100
# 666/666 [==============================] - 2s 3ms/step - loss: 0.0084 - mean_absolute_percentage_error: 4.8470 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 4.5822

# %%
print(hist.history.keys())
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %%
plt.plot(hist.history['mean_absolute_percentage_error'])
plt.plot(hist.history['val_mean_absolute_percentage_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Validation', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Validation', 'test'], loc='upper left')
plt.show()

# %%
score = model.evaluate(x_test_new, y_test_new, verbose=1)
print('Test loss:', score[0])
print(' Heart Rate  MSE:', score[1])
# Out:
# 268/268 [==============================] - 0s 1ms/step - loss: 0.0081 - mean_absolute_percentage_error: 4.1817
# Test loss: 0.008068879134953022
#  Heart Rate  MSE: 4.181652069091797

# %%
fEst = model.predict(x_test_new)

print(x_test_new.shape)
#feed it noisy data to see what happens

#Model it but with a moving heart rate. See what hpapens 
print(fEst)
print(y_test_new.shape)
# Out:
# (8569, 200)
# [[1.435465  ]
#  [1.6153103 ]
#  [1.6805145 ]
#  ...
#  [0.97028685]
#  [0.9893855 ]
#  [1.0061895 ]]
# (8569,)

# %%
x = 500
numShow = 1000
t = np.arange(0,numShow,1)
plt.plot(t,y_test_new[x:x+numShow], t, fEst[x:x+numShow,0])
plt.ylabel('Frequency')
plt.xlabel('Data Index')
plt.legend(['Actual Frequency','Predicted Frequency'])
plt.title('Resp Rate Frequency Estimate Comparison')
plt.show()

# %%
x = 2000
numShow = 500
t = np.arange(0,numShow,1)
plt.plot(t,y_test_new[x:x+numShow], t, fEst[x:x+numShow,0])
plt.ylabel('Frequency')
plt.xlabel('Data Index')
plt.legend(['Actual Frequency','Predicted Frequency'])
plt.title('Resp Rate Frequency Estimate Comparison')
plt.show()

# %%
#save model for futyure use (DO NOT DO EVERY TIME, YOU WILL OVERWRITE A GOOD MODEL)

#model.save('Model_fs500_specModel_RespInc')

# %% [markdown]
# ## Computer Exercise #05 ##
#
# ### Load the Common Imports ###

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
from keras import Input as Input
from keras.datasets import mnist
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D,Conv1D
from keras.models import Sequential
from keras.layers import Dropout
from keras import layers
from keras.layers import BatchNormalization
import h5py
from scipy import signal
print(keras.__version__)
# Out:
# 2.4.3

# %% [markdown]
# # Load Mat Files

# %%
f = h5py.File('ML_genTrain_HRV_honly_fs500_long_1.mat','r')
fs = 500
arrays = {}

for k, v in f.items():
    arrays[k] = np.array(v)

# %% [markdown]
# ### Load the Dataset ###

# %%
print(arrays.keys())
datOut= arrays['datOut']

numOfDat = datOut.shape[0]

heartLabels = arrays['fhActual']
heartLabels = heartLabels.transpose()
heartLabels = heartLabels[:,0:numOfDat]

respLabels = arrays['frActual']
respLabels = respLabels.transpose()
respLabels = respLabels[:,0:numOfDat]
#print(datOut.shape) # 20 thousand different trials each is 16k samples long. +


datLabels = np.empty((2,numOfDat))


#datLabels[0,:] = respLabels
#datLabels[1,:] = heartLabels

datLabels = heartLabels
datLabels= datLabels.transpose()

print('fuck:',datLabels.shape)
tNum = datOut.shape[0]


maxFreq = 1


percentTrain = .9;
trainEndEx = round(tNum*percentTrain)

firstLayerLength = 500

#x_train = datOut[0:trainEndEx,0:firstLayerLength+100]
x_train = datOut[0:trainEndEx,:]

y_train = datLabels[0:trainEndEx,:] / maxFreq

#x_test = datOut[trainEndEx+1:,0:firstLayerLength+100]
x_test = datOut[trainEndEx+1:,:]

y_test = datLabels[trainEndEx+1:numOfDat,:]/maxFreq


# input image dimensions
img_x, img_y = 28, 28
#Reshape the data into a 4d tensor
#x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
#x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
#input_shape = ( x_train.shape[1], 1, 1)
print(x_test.shape)

#x_train = x_train.reshape(-1,firstLayerLength)
#x_test = x_test.reshape(-1,firstLayerLength)


# convert the data to the right type
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')


print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

#print(y_test.shape)
#print(y_train.shape)


#y_test = y_test[:,0]
#y_train = y_train[:,0]

print(y_test.shape)
print(y_train.shape)
# Out:
# dict_keys(['datOut', 'fhActual', 'frActual', 't'])
# fuck: (10000, 25001)
# (999, 25001)
# x_train shape: (9000, 25001)
# 9000 train samples
# 999 test samples
# (999, 25001)
# (9000, 25001)

# %%
#_test = y_test[:,0]
#y_train = y_train[:,0]

#print(y_test.shape)
#print(y_train.shape)

# %%
x = 500
t = np.linspace(0,10,firstLayerLength+100)
print(x_train.shape)
plt.plot(t,x_train[x,:],t,x_train[1,:])
plt.ylabel('some numbers')
plt.show()
print(y_train[x])
# Out:
# (9000, 25001)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e75c0a1ab7b2> in <module>
#       2 t = np.linspace(0,10,firstLayerLength+100)
#       3 print(x_train.shape)
# ----> 4 plt.plot(t,x_train[x,:],t,x_train[1,:])
#       5 plt.ylabel('some numbers')
#       6 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (600,) and (25001,)

# %%
#Find spectrogram of approapate size
winSize = 2048  #This is the window size (found to work best for fs = 500)

win = signal.get_window('hamming',winSize) #Hamming window
f, t, Sxx = signal.spectrogram(x_train[0,:],window=win,fs = fs,noverlap=2000,nfft= 10000) #Find spectrogram with high fft count

Sxx = Sxx[0:50,:] #We only need FFT from 0 to 3ish Hz which is about the first 50 samples at fs=500
f = f[0:50]
idx=np.int0(t*fs)


y=y_train[0,idx]

plt.pcolormesh(t,f,Sxx, shading='gouraud') #Plot it to confirm (dont do this when actually finding it (duh))

plt.ylabel('Frequency [Hz]')

plt.xlabel('Time [sec]')

plt.show()
print(Sxx.shape)
print(y.shape)
# Out:
# (50, 479)
# (479,)

# %%
#This cell creates the training data (take 200 different spectrograms and append them one after another)
#Each stripe of data (vertically down the HZ) is a training point with a single bit of data

winSize = 2048  #This is the window size (found to work best for fs = 500)

win = signal.get_window('hamming',winSize) #Hamming window

x_train_new = np.empty
for k in range(0,200,1):
    f, t, Sxx = signal.spectrogram(x_train[k,:],window=win,fs = fs,noverlap=2000,nfft= 10000) #Find spectrogram with high fft count
    Sxx = Sxx[0:50,:] #We only need FFT from 0 to 3ish Hz which is about the first 50 samples at fs=500
    f = f[0:50]
    if k ==0:
        x_train_new = Sxx
        y_train_new = y_train[k,round(t*fs)]
        y_train[k,:]
    else:
        x_train_new = np.append(x_train_new,Sxx,1)

# %%
print(x_train_new.shape)
print(477*200)
print(Sxx.shape)


plt.pcolormesh(x_train_new, shading='gouraud') #Plot it to confirm (dont do this when actually finding it (duh))

plt.ylabel('Frequency [Hz]')

plt.xlabel('Time [sec]')

plt.show()
# Out:
# (50, 95800)
# 95400
# (50, 479)

# %% [markdown]
# # Set up Model

# %% [markdown]
# model = Sequential()
#
#
# model.add(Conv1D(5, 1, input_shape=(x_train.shape[1], 1)))
# model.add(Flatten())

# %%
model = Sequential()
#model.add(Conv1D(5, 5, input_shape=(x_train.shape[1], 1)))
model.add(Input(shape=(x_train.shape[1], )))

model.add(Dense(2,input_shape  = (x_train.shape[1],)))
model.add(Dense(2))
model.add(Dense(3))
model.add(Dense(1))

# %%
#model.compile(loss=keras.losses.mean_squared_logarithmic_error,
#              optimizer=keras.optimizers.Adam(),
#                  metrics=[keras.metrics.MeanSquaredError()])
#model.summary()

model.compile(loss=keras.losses.mean_absolute_percentage_error,
              optimizer=keras.optimizers.Nadam(learning_rate=0.001),metrics=[keras.metrics.mape])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2)                 1202
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 9
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 1,221
# Trainable params: 1,221
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Convert class vectors to binary class matrices ###
#
# This is the one to use with the `categorical_crossentropy` loss.

# %%
batch_size = 1  # Set the batch size
epochs =20# Set the number of epochs
# One Hidden Layer
print(model.inputs[0].dtype)
# Out:
# <dtype: 'float32'>

# %% [markdown]
# ### Train the Model ###

# %%
# One Hidden Layer
initializer = keras.initializers.RandomNormal(mean=0., stddev=5.)

hist = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_split=0.18,
          callbacks=None)



score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/20
# 73800/73800 [==============================] - 71s 951us/step - loss: 2.2121 - mean_absolute_percentage_error: 2.2121 - val_loss: 0.1962 - val_mean_absolute_percentage_error: 0.1962
# Epoch 2/20
# 73800/73800 [==============================] - 70s 942us/step - loss: 0.2733 - mean_absolute_percentage_error: 0.2733 - val_loss: 0.2218 - val_mean_absolute_percentage_error: 0.2218
# Epoch 3/20
# 73800/73800 [==============================] - 71s 964us/step - loss: 0.2643 - mean_absolute_percentage_error: 0.2643 - val_loss: 0.2769 - val_mean_absolute_percentage_error: 0.2769
# Epoch 4/20
# 73800/73800 [==============================] - 70s 950us/step - loss: 0.2581 - mean_absolute_percentage_error: 0.2581 - val_loss: 0.3598 - val_mean_absolute_percentage_error: 0.3598
# Epoch 5/20
# 73800/73800 [==============================] - 69s 935us/step - loss: 0.2499 - mean_absolute_percentage_error: 0.2499 - val_loss: 0.1760 - val_mean_absolute_percentage_error: 0.1760
# Epoch 6/20
# 73800/73800 [==============================] - 69s 937us/step - loss: 0.2481 - mean_absolute_percentage_error: 0.2481 - val_loss: 0.1589 - val_mean_absolute_percentage_error: 0.1589
# Epoch 7/20
# 73800/73800 [==============================] - 69s 932us/step - loss: 0.2417 - mean_absolute_percentage_error: 0.2417 - val_loss: 0.3850 - val_mean_absolute_percentage_error: 0.3850
# Epoch 8/20
# 73800/73800 [==============================] - 68s 918us/step - loss: 0.2398 - mean_absolute_percentage_error: 0.2398 - val_loss: 0.4912 - val_mean_absolute_percentage_error: 0.4912
# Epoch 9/20
# 73800/73800 [==============================] - 72s 977us/step - loss: 0.2347 - mean_absolute_percentage_error: 0.2347 - val_loss: 0.1793 - val_mean_absolute_percentage_error: 0.1793
# Epoch 10/20
# 73800/73800 [==============================] - 64s 863us/step - loss: 0.2315 - mean_absolute_percentage_error: 0.2315 - val_loss: 0.2505 - val_mean_absolute_percentage_error: 0.2505
# Epoch 11/20
# 73800/73800 [==============================] - 65s 879us/step - loss: 0.2290 - mean_absolute_percentage_error: 0.2290 - val_loss: 0.2167 - val_mean_absolute_percentage_error: 0.2167
# Epoch 12/20
# 73800/73800 [==============================] - 64s 872us/step - loss: 0.2245 - mean_absolute_percentage_error: 0.2245 - val_loss: 0.2267 - val_mean_absolute_percentage_error: 0.2267
# Epoch 13/20
# 73800/73800 [==============================] - 64s 868us/step - loss: 0.2207 - mean_absolute_percentage_error: 0.2207 - val_loss: 0.1535 - val_mean_absolute_percentage_error: 0.1535
# Epoch 14/20
# 73800/73800 [==============================] - 63s 852us/step - loss: 0.2160 - mean_absolute_percentage_error: 0.2160 - val_loss: 0.1730 - val_mean_absolute_percentage_error: 0.1730
# Epoch 15/20
# 73800/73800 [==============================] - 63s 859us/step - loss: 0.2141 - mean_absolute_percentage_error: 0.2141 - val_loss: 0.1485 - val_mean_absolute_percentage_error: 0.1485
# Epoch 16/20
# 73800/73800 [==============================] - 63s 858us/step - loss: 0.2121 - mean_absolute_percentage_error: 0.2121 - val_loss: 0.3897 - val_mean_absolute_percentage_error: 0.3897
# Epoch 17/20
# 73800/73800 [==============================] - 63s 850us/step - loss: 0.2116 - mean_absolute_percentage_error: 0.2116 - val_loss: 0.1554 - val_mean_absolute_percentage_error: 0.1554
# Epoch 18/20
# 73800/73800 [==============================] - 63s 848us/step - loss: 0.2062 - mean_absolute_percentage_error: 0.2062 - val_loss: 0.2411 - val_mean_absolute_percentage_error: 0.2411
# Epoch 19/20
# 73800/73800 [==============================] - 64s 866us/step - loss: 0.2037 - mean_absolute_percentage_error: 0.2037 - val_loss: 0.1682 - val_mean_absolute_percentage_error: 0.1682
# Epoch 20/20
# 73800/73800 [==============================] - 64s 866us/step - loss: 0.2027 - mean_absolute_percentage_error: 0.2027 - val_loss: 0.2857 - val_mean_absolute_percentage_error: 0.2857
# Test loss: 0.284711629152298
# Test accuracy: 0.284711629152298

# %%
fEst = model.predict(x_test)

print(x_test.shape)
#feed it noisy data to see what happens

#Model it but with a moving heart rate. See what hpapens 
print(fEst)
print(y_test)
# Out:
# (9999, 600)
# [[1.0500183]
#  [1.349936 ]
#  [1.5042312]
#  ...
#  [1.050205 ]
#  [1.3304625]
#  [1.3135748]]
# [1.04538874 1.34607405 1.50277821 ... 1.04831612 1.32800497 1.30739582]

# %% [markdown]
# # Old Code ( for 2d Image CNN)
# model = Sequential()
# model.add(Input(shape=(32,32,1)))
#
# model.add(Conv2D(32, kernel_size=(3, 3), strides=(1, 1), activation='relu'))
# model.add(Dropout(rate = .01,seed = 7))
# model.add(MaxPooling2D(pool_size=(5, 5),strides=(2,2),padding='same'))
# model.add(Conv2D(64, (7,7), activation='relu'))
#
# model.add(BatchNormalization(axis=3,trainable=True))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Flatten())
# model.add(Dense(1000, activation='relu'))
# model.add(Dense(num_classes, activation='softmax'))

# %%
numShow = 20
t = np.arange(0,numShow,1)
plt.plot(t,y_test[0:numShow], t, fEst[0:numShow,0])
plt.ylabel('Frequency')
plt.xlabel('Test Num')
plt.legend(['Actual Frequency','Predicted Frequency'])
plt.title('Resp Rate Frequency Estimate Comparison')
plt.show()

# %%
numShow = 20
t = np.arange(0,numShow,1)
plt.plot(t,y_test[0:numShow,1], t, fEst[0:numShow,1])
plt.ylabel('Frequency')
plt.xlabel('Test Num')
plt.legend(['Actual Frequency','Predicted Frequency'])
plt.title('Heart Rate Frequency Estimate Comparison')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-211306500cfc> in <module>
#       1 numShow = 20
#       2 t = np.arange(0,numShow,1)
# ----> 3 plt.plot(t,y_test[0:numShow,1], t, fEst[0:numShow,1])
#       4 plt.ylabel('Frequency')
#       5 plt.xlabel('Test Num')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
t = np.arange(0,1495,1)
plt.plot(t,abs(y_test[:,0]-fEst[:,0])/y_test[:,0])
plt.ylabel('Percent Error')
plt.xlabel('Test Num')
plt.title(' Resp Rate Percent Error For Testing data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-bf7ad2f9a812> in <module>
#       1 t = np.arange(0,1495,1)
# ----> 2 plt.plot(t,abs(y_test[:,0]-fEst[:,0])/y_test[:,0])
#       3 plt.ylabel('Percent Error')
#       4 plt.xlabel('Test Num')
#       5 plt.title(' Resp Rate Percent Error For Testing data')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
t = np.arange(0,1495,1)
plt.plot(t,abs(y_test[:,1]-fEst[:,1])/y_test[:,1])
plt.ylabel('Percent Error')
plt.xlabel('Test Num')
plt.title(' Heart Rate Percent Error For Testing data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-8dbaf118e790> in <module>
#       1 t = np.arange(0,1495,1)
# ----> 2 plt.plot(t,abs(y_test[:,1]-fEst[:,1])/y_test[:,1])
#       3 plt.ylabel('Percent Error')
#       4 plt.xlabel('Test Num')
#       5 plt.title(' Heart Rate Percent Error For Testing data')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
t = np.arange(0,50,1)
plt.plot(t,abs(y_test[0:50,1]-fEst[0:50,1])/y_test[0:50,1])
plt.ylabel('Percent Error')
plt.xlabel('Test Num')
plt.title(' Heart Rate Percent Error For Testing data')
plt.show()

# %%
#save model for futyure use (DO NOT DO EVERY TIME, YOU WILL OVERWRITE A GOOD MODEL)

model.save('Model_fs500_honly_500')
# Out:
# INFO:tensorflow:Assets written to: Model_fs500_honly_500/assets
